# %% [markdown]
# # Data Preprocessing
# ## Import data and get an overview
# <a target="_blank" href="https://colab.research.google.com/github/LuWidme/uk259/blob/main/demos/Data%20Preprocessing.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
#
# This exercise explores the Melbourne housing market using this [Dataset]("https://www.kaggle.com/datasets/anthonypino/melbourne-housing-market/data), containing residential property sales data across Melbourne.
#
# The Link includes descriptions of the variables.

# %%
import pandas as pd

import numpy as np
data_root = "https://raw.githubusercontent.com/LuWidme/uk259/main/"

df=pd.read_csv(data_root +"/datasets/melb_data.csv")
# add additional column for demonstration purpose
df["Yard"]= np.random.choice(["none", "small", "medium", "large"], df.shape[0])
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...  2.0     120.0
# ...         ...         ...       ...       ...  ...  ...       ...
# 13575     Barry  26/08/2017      16.7    3150.0  ...  2.0     652.0
# 13576  Williams  26/08/2017       6.8    3016.0  ...  2.0     333.0
# 13577     Raine  26/08/2017       6.8    3016.0  ...  4.0     436.0
# 13578   Sweeney  26/08/2017       6.8    3016.0  ...  5.0     866.0
# 13579   Village  26/08/2017       6.3    3013.0  ...  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea  Lattitude Longtitude  \
# 0               NaN        NaN        Yarra  -37.79960  144.99840
# 1              79.0     1900.0        Yarra  -37.80790  144.99340
# 2             150.0     1900.0        Yarra  -37.80930  144.99440
# 3               NaN        NaN        Yarra  -37.79690  144.99690
# 4             142.0     2014.0        Yarra  -37.80720  144.99410
# ...             ...        ...          ...        ...        ...
# 13575           NaN     1981.0          NaN  -37.90562  145.16761
# 13576         133.0     1995.0          NaN  -37.85927  144.87904
# 13577           NaN     1997.0          NaN  -37.85274  144.88738
# 13578         157.0     1920.0          NaN  -37.85908  144.89299
# 13579         112.0     1920.0          NaN  -37.81188  144.88449
#
#                        Regionname  Propertycount    Yard
# 0           Northern Metropolitan         4019.0    none
# 1           Northern Metropolitan         4019.0   small
# 2           Northern Metropolitan         4019.0  medium
# 3           Northern Metropolitan         4019.0   large
# 4           Northern Metropolitan         4019.0   large
# ...                           ...            ...     ...
# 13575  South-Eastern Metropolitan         7392.0   large
# 13576        Western Metropolitan         6380.0    none
# 13577        Western Metropolitan         6380.0   small
# 13578        Western Metropolitan         6380.0   small
# 13579        Western Metropolitan         6543.0   small
#
# [13580 rows x 22 columns]

# %% [markdown]
# # Repetition boolean indexing & Filtering

# %%
df["Rooms"]>2
#df[(df["Rooms"]>5)]
#df[(df["Rooms"]>2) & (df["SellerG"]!="Biggin")][["Postcode", "Price"]].iloc[:10,:]
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 13575     True
# 13576     True
# 13577     True
# 13578     True
# 13579     True
# Name: Rooms, Length: 13580, dtype: bool

# %% [markdown]
# # Initial Data Exploration

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df["Price"])
max(df["Price"])
# Out:
# 9000000.0

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.countplot(data=df, x='Regionname', ax=ax)
ax.tick_params(axis='x', labelrotation=45)
plt.show()

# %%
print("shape:\n", df.shape)
print("\ndatatypes:\n",df.dtypes)
print("\nstatistics: \n",df.describe())
print("\nnull values: \n",df.isnull().sum())
# Out:
# shape:
#  (13580, 22)
#
# datatypes:
#  Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# Yard              object
# dtype: object
#
# statistics:
#                Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# std        0.691712      0.962634    3990.669241    541.014538    37.273762
# min        0.000000      0.000000       0.000000      0.000000  1196.000000
# 25%        1.000000      1.000000     177.000000     93.000000  1940.000000
# 50%        1.000000      2.000000     440.000000    126.000000  1970.000000
# 75%        2.000000      2.000000     651.000000    174.000000  1999.000000
# max        8.000000     10.000000  433014.000000  44515.000000  2018.000000
#
#           Lattitude    Longtitude  Propertycount
# count  13580.000000  13580.000000   13580.000000
# mean     -37.809203    144.995216    7454.417378
# std        0.079260      0.103916    4378.581772
# min      -38.182550    144.431810     249.000000
# 25%      -37.856822    144.929600    4380.000000
# 50%      -37.802355    145.000100    6555.000000
# 75%      -37.756400    145.058305   10331.000000
# max      -37.408530    145.526350   21650.000000
#
# null values:
#  Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# Yard                0
# dtype: int64

# %% [markdown]
# ## Remove missing values
#
# dropna() takes various parameters like —
# * axis — We can specify axis=0 if we want to remove the rows and axis=1 if we want to remove the columns.
# * how — If we specify how = ‘all’ then the rows and columns will only be dropped if all the values are NaN.By default how is set to ‘any’.
# * thresh — It determines the threshold value so if we specify thresh=5 then the rows having less than 5 real values will be dropped.
# * subset —If we have 4 columns A, B, C and D then if we specify subset=[‘C’] then only the rows that have their C value as NaN will be removed.
# * inplace — By default, no changes will be made to your dataframe. So if you want these changes to reflect onto your dataframe then you need to use inplace = True.
#
#
# **decide on a strategy to handle the missing parameters and implement it.**

# %%
print ("number of entries wit at least 1 NA: ", sum(df.isnull().any(axis=1)))
df.dropna().shape
# Out:
# number of entries wit at least 1 NA:  7384
# (6196, 22)

# %% [markdown]
# ## Standardization
# In Standardization, we transform our values such that the mean of the values is 0 and the standard deviation is 1.
# The important thing to note here is that we need to standardize both training and testing data.\
# Skleanr Standardsacale implemnts a simple Scaler for us.
#
# `fit()` calculates the mean and standard deviation and the `transform()` function actually standardizes the dataset.\
# We can do this process in a single line of code using the `fit_transform()` function.\

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
df[['Rooms_standardized','Price_standardized']] = std.fit_transform(df[['Rooms','Price']])
df[['Rooms_standardized','Price_standardized']]
# Out:
#        Rooms_standardized  Price_standardized
# 0               -0.981463            0.632448
# 1               -0.981463           -0.063640
# 2                0.064876            0.608984
# 3                0.064876           -0.353025
# 4                1.111216            0.820157
# ...                   ...                 ...
# 13575            1.111216            0.264851
# 13576            0.064876           -0.069897
# 13577            0.064876            0.147533
# 13578            1.111216            2.227975
# 13579            1.111216            0.327421
#
# [13580 rows x 2 columns]

# %% [markdown]
# ## Questions:
# * Does it make sense to standardize Postcode, Longitude, Propertycount, Distance?
# * How can you interpret the fact that a hosue has a standardized prize of `-1.0`?

# %% [markdown]
# ## Handling categorical variables
#
# We need to preprocess ordinal and nominal categorical variables differently to make them interpretable for many machine learning algorithms. Here are some techniques one can use to encode Categorical values, such as:
#
# * Replacing values
# * Encoding labels
# * One-Hot encoding
# * Binary encoding
#
# Typecasting categrical variables to "category" is generally recommended for performance. for easy label encoding it is even necessary:

# %%
df["Suburb_encoded"]=df["Suburb"].astype("category").cat.codes
df[["Suburb","Suburb_encoded"]].astype("category")
# Out:
#               Suburb Suburb_encoded
# 0         Abbotsford              0
# 1         Abbotsford              0
# 2         Abbotsford              0
# 3         Abbotsford              0
# 4         Abbotsford              0
# ...              ...            ...
# 13575  Wheelers Hill            302
# 13576   Williamstown            305
# 13577   Williamstown            305
# 13578   Williamstown            305
# 13579     Yarraville            313
#
# [13580 rows x 2 columns]

# %% [markdown]
# A different startegy to deal with categorical data is called "One-Hot Encoding":

# %%
print('Data:')
print(df)
print(df.shape)

# Remove all columns expecpt for price, SellerG and regionName
df = df[["Price", "SellerG", "Regionname"]]
df

# Count how much things every seller sells and find the top 2 sellers
top_sellers = df.groupby("SellerG").count().sort_values("Price",ascending=False).head(2).index
top_sellers
print('Show top 2 sellers:')
print(top_sellers)

# Count how many houses per region
top_regions = df.groupby("Regionname").count().sort_values("Price",ascending=False).head(3).index
print('Show top 3 regions:')
print(top_regions)

# Display a violin diagram with top regions, sellers and prices
filtered_df = df[(df["SellerG"].isin(top_sellers)) & (df["Regionname"].isin(top_regions))]

sns.violinplot(x="Regionname", y="Price", hue="SellerG", data=filtered_df, split=True)
plt.xticks(rotation=45)
# Out:
# Data:
#            Price   SellerG                  Regionname
# 0      1480000.0    Biggin       Northern Metropolitan
# 1      1035000.0    Biggin       Northern Metropolitan
# 2      1465000.0    Biggin       Northern Metropolitan
# 3       850000.0    Biggin       Northern Metropolitan
# 4      1600000.0    Nelson       Northern Metropolitan
# ...          ...       ...                         ...
# 13575  1245000.0     Barry  South-Eastern Metropolitan
# 13576  1031000.0  Williams        Western Metropolitan
# 13577  1170000.0     Raine        Western Metropolitan
# 13578  2500000.0   Sweeney        Western Metropolitan
# 13579  1285000.0   Village        Western Metropolitan
#
# [13580 rows x 3 columns]
# (13580, 3)
# Show top 2 sellers:
# Index(['Nelson', 'Jellis'], dtype='object', name='SellerG')
# Show top 3 regions:
# Index(['Southern Metropolitan', 'Northern Metropolitan',
#        'Western Metropolitan'],
#       dtype='object', name='Regionname')
# <Axes: xlabel='Regionname', ylabel='Price'>

# %% [markdown]
# ## Exercise
#
# Pick one Variable in the Dataset above (e.g Price) and try to draw some conclusion about the data (e.g. how are prices distributed across the dataset, what is the highest/lowest price, how different are prices across regions, etc.)
# If you have time, try to visualize this finding in a graph.
